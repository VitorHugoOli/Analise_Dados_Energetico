# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from sklearn.linear_model import LinearRegression

# %%
xls = pd.ExcelFile('../data/WorldEnergyBalancesHighlights_final.xlsx')

# %%
df = pd.read_excel(xls, 'TimeSeries_1971-2019',header=1,index_col=[0,1,2],usecols="A:C,Z:BB",na_values=['..','c'])
df
# Out:
#                                                                                                                   1990  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.061030e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -6.726662e+04
#                                                                  Total energy supply (ktoe)               3.488774e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -2.892349e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 9.046845e+06
# World                                   Fossil fuels             Electricity output (GWh)                 7.501510e+06
#                                         Nuclear                  Electricity output (GWh)                 2.012902e+06
#                                         Renewable sources        Electricity output (GWh)                 2.296008e+06
#                                         Total                    Electricity output (GWh)                 1.184619e+07
#
#                                                                                                                   1991  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.147629e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -7.821431e+04
#                                                                  Total energy supply (ktoe)               3.627799e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -2.994731e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 9.328546e+06
# World                                   Fossil fuels             Electricity output (GWh)                 7.635090e+06
#                                         Nuclear                  Electricity output (GWh)                 2.105787e+06
#                                         Renewable sources        Electricity output (GWh)                 2.331754e+06
#                                         Total                    Electricity output (GWh)                 1.211372e+07
#
#                                                                                                                   1992  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.191394e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -8.201214e+04
#                                                                  Total energy supply (ktoe)               3.683188e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.072018e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 9.504321e+06
# World                                   Fossil fuels             Electricity output (GWh)                 7.711052e+06
#                                         Nuclear                  Electricity output (GWh)                 2.123688e+06
#                                         Renewable sources        Electricity output (GWh)                 2.345052e+06
#                                         Total                    Electricity output (GWh)                 1.222526e+07
#
#                                                                                                                   1993  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.199827e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -8.562526e+04
#                                                                  Total energy supply (ktoe)               3.755881e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.091807e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 9.818359e+06
# World                                   Fossil fuels             Electricity output (GWh)                 7.804674e+06
#                                         Nuclear                  Electricity output (GWh)                 2.190502e+06
#                                         Renewable sources        Electricity output (GWh)                 2.478493e+06
#                                         Total                    Electricity output (GWh)                 1.251388e+07
#
#                                                                                                                   1994  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.186872e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -8.512007e+04
#                                                                  Total energy supply (ktoe)               3.711308e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.130889e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.019072e+07
# World                                   Fossil fuels             Electricity output (GWh)                 8.027545e+06
#                                         Nuclear                  Electricity output (GWh)                 2.242299e+06
#                                         Renewable sources        Electricity output (GWh)                 2.506853e+06
#                                         Total                    Electricity output (GWh)                 1.282045e+07
#
#                                                                                                                   1995  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.278234e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -8.859445e+04
#                                                                  Total energy supply (ktoe)               3.749816e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.238343e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.058758e+07
# World                                   Fossil fuels             Electricity output (GWh)                 8.243082e+06
#                                         Nuclear                  Electricity output (GWh)                 2.331951e+06
#                                         Renewable sources        Electricity output (GWh)                 2.630939e+06
#                                         Total                    Electricity output (GWh)                 1.325263e+07
#
#                                                                                                                   1996  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.299562e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -9.132449e+04
#                                                                  Total energy supply (ktoe)               4.068682e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.429146e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.097046e+07
# World                                   Fossil fuels             Electricity output (GWh)                 8.540865e+06
#                                         Nuclear                  Electricity output (GWh)                 2.417194e+06
#                                         Renewable sources        Electricity output (GWh)                 2.667565e+06
#                                         Total                    Electricity output (GWh)                 1.367503e+07
#
#                                                                                                                   1997  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.406763e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -1.015400e+05
#                                                                  Total energy supply (ktoe)               4.432821e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.550844e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.121283e+07
# World                                   Fossil fuels             Electricity output (GWh)                 8.814176e+06
#                                         Nuclear                  Electricity output (GWh)                 2.393101e+06
#                                         Renewable sources        Electricity output (GWh)                 2.708264e+06
#                                         Total                    Electricity output (GWh)                 1.396587e+07
#
#                                                                                                                   1998  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.524274e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -1.080667e+05
#                                                                  Total energy supply (ktoe)               4.712117e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.002470e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.150476e+07
# World                                   Fossil fuels             Electricity output (GWh)                 9.100734e+06
#                                         Nuclear                  Electricity output (GWh)                 2.445210e+06
#                                         Renewable sources        Electricity output (GWh)                 2.729731e+06
#                                         Total                    Electricity output (GWh)                 1.432437e+07
#
#                                                                                                                   1999  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        1.545393e+05
#                                                                  Imports (ktoe)                           0.000000e+00
#                                                                  Exports (ktoe)                          -1.117012e+05
#                                                                  Total energy supply (ktoe)               4.809330e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.063557e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.183663e+07
# World                                   Fossil fuels             Electricity output (GWh)                 9.396966e+06
#                                         Nuclear                  Electricity output (GWh)                 2.531148e+06
#                                         Renewable sources        Electricity output (GWh)                 2.755743e+06
#                                         Total                    Electricity output (GWh)                 1.473425e+07
#
#                                                                                                           ...  \
# Country                                 Product                  Flow                                     ...
# Australia                               Coal, peat and oil shale Production (ktoe)                        ...
#                                                                  Imports (ktoe)                           ...
#                                                                  Exports (ktoe)                           ...
#                                                                  Total energy supply (ktoe)               ...
#                                                                  Electricity, CHP and heat plants (ktoe)  ...
# ...                                                                                                       ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 ...
# World                                   Fossil fuels             Electricity output (GWh)                 ...
#                                         Nuclear                  Electricity output (GWh)                 ...
#                                         Renewable sources        Electricity output (GWh)                 ...
#                                         Total                    Electricity output (GWh)                 ...
#
#                                                                                                                   2009  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.233330e+05
#                                                                  Imports (ktoe)                           3.869300e+00
#                                                                  Exports (ktoe)                          -1.690482e+05
#                                                                  Total energy supply (ktoe)               5.267070e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.828301e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.607797e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.347941e+07
#                                         Nuclear                  Electricity output (GWh)                 2.696181e+06
#                                         Renewable sources        Electricity output (GWh)                 3.900559e+06
#                                         Total                    Electricity output (GWh)                 2.014633e+07
#
#                                                                                                                   2010  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.465636e+05
#                                                                  Imports (ktoe)                           4.262450e+01
#                                                                  Exports (ktoe)                          -1.903909e+05
#                                                                  Total energy supply (ktoe)               5.047003e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.483156e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.717960e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.447437e+07
#                                         Nuclear                  Electricity output (GWh)                 2.756288e+06
#                                         Renewable sources        Electricity output (GWh)                 4.203229e+06
#                                         Total                    Electricity output (GWh)                 2.152387e+07
#
#                                                                                                                   2011  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.336407e+05
#                                                                  Imports (ktoe)                           1.613556e+02
#                                                                  Exports (ktoe)                          -1.843984e+05
#                                                                  Total energy supply (ktoe)               4.809913e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.273424e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.776476e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.511943e+07
#                                         Nuclear                  Electricity output (GWh)                 2.582640e+06
#                                         Renewable sources        Electricity output (GWh)                 4.414623e+06
#                                         Total                    Electricity output (GWh)                 2.221193e+07
#
#                                                                                                                   2012  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.453512e+05
#                                                                  Imports (ktoe)                           8.683070e+01
#                                                                  Exports (ktoe)                          -1.951614e+05
#                                                                  Total energy supply (ktoe)               4.702515e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -4.227410e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.812718e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.544395e+07
#                                         Nuclear                  Electricity output (GWh)                 2.460285e+06
#                                         Renewable sources        Electricity output (GWh)                 4.734792e+06
#                                         Total                    Electricity output (GWh)                 2.273578e+07
#
#                                                                                                                   2013  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.645165e+05
#                                                                  Imports (ktoe)                           6.156230e+01
#                                                                  Exports (ktoe)                          -2.173751e+05
#                                                                  Total energy supply (ktoe)               4.373756e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.941945e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.869713e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.577336e+07
#                                         Nuclear                  Electricity output (GWh)                 2.479105e+06
#                                         Renewable sources        Electricity output (GWh)                 5.065217e+06
#                                         Total                    Electricity output (GWh)                 2.341798e+07
#
#                                                                                                                   2014  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.854397e+05
#                                                                  Imports (ktoe)                           1.262876e+02
#                                                                  Exports (ktoe)                          -2.428319e+05
#                                                                  Total energy supply (ktoe)               4.147830e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.728509e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.900883e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.590751e+07
#                                         Nuclear                  Electricity output (GWh)                 2.535405e+06
#                                         Renewable sources        Electricity output (GWh)                 5.299179e+06
#                                         Total                    Electricity output (GWh)                 2.384443e+07
#
#                                                                                                                   2015  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.985813e+05
#                                                                  Imports (ktoe)                           1.666857e+02
#                                                                  Exports (ktoe)                          -2.539994e+05
#                                                                  Total energy supply (ktoe)               4.292146e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.875769e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.929751e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.608776e+07
#                                         Nuclear                  Electricity output (GWh)                 2.570070e+06
#                                         Renewable sources        Electricity output (GWh)                 5.522462e+06
#                                         Total                    Electricity output (GWh)                 2.428035e+07
#
#                                                                                                                   2016  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.919546e+05
#                                                                  Imports (ktoe)                           1.631316e+02
#                                                                  Exports (ktoe)                          -2.520423e+05
#                                                                  Total energy supply (ktoe)               4.449822e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.986017e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 1.983341e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.632508e+07
#                                         Nuclear                  Electricity output (GWh)                 2.608402e+06
#                                         Renewable sources        Electricity output (GWh)                 5.926002e+06
#                                         Total                    Electricity output (GWh)                 2.496774e+07
#
#                                                                                                                   2017  \
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.930263e+05
#                                                                  Imports (ktoe)                           1.890881e+02
#                                                                  Exports (ktoe)                          -2.447700e+05
#                                                                  Total energy supply (ktoe)               4.445229e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.918542e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 2.036404e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.659544e+07
#                                         Nuclear                  Electricity output (GWh)                 2.636117e+06
#                                         Renewable sources        Electricity output (GWh)                 6.268171e+06
#                                         Total                    Electricity output (GWh)                 2.561200e+07
#
#                                                                                                                   2018
# Country                                 Product                  Flow
# Australia                               Coal, peat and oil shale Production (ktoe)                        2.874423e+05
#                                                                  Imports (ktoe)                           3.041877e+02
#                                                                  Exports (ktoe)                          -2.468082e+05
#                                                                  Total energy supply (ktoe)               4.293614e+04
#                                                                  Electricity, CHP and heat plants (ktoe) -3.759278e+04
# ...                                                                                                                ...
# IEA and Accession/Association countries Total                    Electricity output (GWh)                 2.120109e+07
# World                                   Fossil fuels             Electricity output (GWh)                 1.709355e+07
#                                         Nuclear                  Electricity output (GWh)                 2.710430e+06
#                                         Renewable sources        Electricity output (GWh)                 6.700116e+06
#                                         Total                    Electricity output (GWh)                 2.661888e+07
#
# [6048 rows x 29 columns]

# %%
br = df.loc[('Brazil')]
br
# Out:
#                                                                          1990  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1931.4685
#                          Imports (ktoe)                             7904.0236
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                 9671.0042
#                          Electricity, CHP and heat plants (ktoe)   -1502.8617
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            15829.1115
# Fossil fuels             Electricity output (GWh)                  10017.0000
# Nuclear                  Electricity output (GWh)                   2237.0000
# Renewable sources        Electricity output (GWh)                 210567.0000
# Total                    Electricity output (GWh)                 222821.0000
#
#                                                                          1991  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2115.3928
#                          Imports (ktoe)                             8701.2099
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                11056.9885
#                          Electricity, CHP and heat plants (ktoe)   -1730.6859
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            15296.4559
# Fossil fuels             Electricity output (GWh)                  11154.0000
# Nuclear                  Electricity output (GWh)                   1442.0000
# Renewable sources        Electricity output (GWh)                 221781.0000
# Total                    Electricity output (GWh)                 234377.0000
#
#                                                                          1992  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1886.5141
#                          Imports (ktoe)                             8376.9024
#                          Exports (ktoe)                               -3.9900
#                          Total energy supply (ktoe)                10701.7580
#                          Electricity, CHP and heat plants (ktoe)   -1736.8784
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            15591.3750
# Fossil fuels             Electricity output (GWh)                  11731.0000
# Nuclear                  Electricity output (GWh)                   1759.0000
# Renewable sources        Electricity output (GWh)                 228242.0000
# Total                    Electricity output (GWh)                 241732.0000
#
#                                                                          1993  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1832.8766
#                          Imports (ktoe)                             8881.1814
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                11010.8661
#                          Electricity, CHP and heat plants (ktoe)   -1656.4288
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            16011.7609
# Fossil fuels             Electricity output (GWh)                  11515.0000
# Nuclear                  Electricity output (GWh)                    442.0000
# Renewable sources        Electricity output (GWh)                 240019.0000
# Total                    Electricity output (GWh)                 251976.0000
#
#                                                                          1994  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2033.9175
#                          Imports (ktoe)                             9318.4725
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                11307.2081
#                          Electricity, CHP and heat plants (ktoe)   -1523.3242
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            17208.2165
# Fossil fuels             Electricity output (GWh)                  11893.0000
# Nuclear                  Electricity output (GWh)                     55.0000
# Renewable sources        Electricity output (GWh)                 248093.0000
# Total                    Electricity output (GWh)                 260041.0000
#
#                                                                          1995  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2051.5905
#                          Imports (ktoe)                             9804.7947
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                11863.3565
#                          Electricity, CHP and heat plants (ktoe)   -1748.8380
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            17217.0882
# Fossil fuels             Electricity output (GWh)                  13583.0000
# Nuclear                  Electricity output (GWh)                   2519.0000
# Renewable sources        Electricity output (GWh)                 259499.0000
# Total                    Electricity output (GWh)                 275601.0000
#
#                                                                          1996  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1889.5063
#                          Imports (ktoe)                            10402.9377
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                12227.1844
#                          Electricity, CHP and heat plants (ktoe)   -1784.8123
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            17631.1770
# Fossil fuels             Electricity output (GWh)                  16328.0000
# Nuclear                  Electricity output (GWh)                   2427.0000
# Renewable sources        Electricity output (GWh)                 272523.0000
# Total                    Electricity output (GWh)                 291278.0000
#
#                                                                          1997  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2180.5680
#                          Imports (ktoe)                            10332.0947
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                12305.7068
#                          Electricity, CHP and heat plants (ktoe)   -2076.8933
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            19922.2008
# Fossil fuels             Electricity output (GWh)                  18458.0000
# Nuclear                  Electricity output (GWh)                   3169.0000
# Renewable sources        Electricity output (GWh)                 286355.0000
# Total                    Electricity output (GWh)                 307982.0000
#
#                                                                          1998  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2094.9357
#                          Imports (ktoe)                            10266.0398
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                12016.3555
#                          Electricity, CHP and heat plants (ktoe)   -2037.4029
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            19879.2834
# Fossil fuels             Electricity output (GWh)                  19504.0000
# Nuclear                  Electricity output (GWh)                   3265.0000
# Renewable sources        Electricity output (GWh)                 298979.0000
# Total                    Electricity output (GWh)                 321748.0000
#
#                                                                          1999  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2144.5393
#                          Imports (ktoe)                             9710.1068
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                12199.7187
#                          Electricity, CHP and heat plants (ktoe)   -2895.6423
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            20583.9033
# Fossil fuels             Electricity output (GWh)                  29005.0000
# Nuclear                  Electricity output (GWh)                   3977.0000
# Renewable sources        Electricity output (GWh)                 301368.0000
# Total                    Electricity output (GWh)                 334716.0000
#
#                                                                   ...  \
# Product                  Flow                                     ...
# Coal, peat and oil shale Production (ktoe)                        ...
#                          Imports (ktoe)                           ...
#                          Exports (ktoe)                           ...
#                          Total energy supply (ktoe)               ...
#                          Electricity, CHP and heat plants (ktoe)  ...
# ...                                                               ...
# Total                    Other final consumption (ktoe)           ...
# Fossil fuels             Electricity output (GWh)                 ...
# Nuclear                  Electricity output (GWh)                 ...
# Renewable sources        Electricity output (GWh)                 ...
# Total                    Electricity output (GWh)                 ...
#
#                                                                          2009  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2239.3252
#                          Imports (ktoe)                             9076.1311
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                10980.4936
#                          Electricity, CHP and heat plants (ktoe)   -2583.4206
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            23812.4476
# Fossil fuels             Electricity output (GWh)                  37753.0000
# Nuclear                  Electricity output (GWh)                  12957.0000
# Renewable sources        Electricity output (GWh)                 414828.0000
# Total                    Electricity output (GWh)                 466121.0000
#
#                                                                          2010  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2104.7433
#                          Imports (ktoe)                            12109.8825
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                14468.1937
#                          Electricity, CHP and heat plants (ktoe)   -3136.7431
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            27167.6695
# Fossil fuels             Electricity output (GWh)                  63878.0000
# Nuclear                  Electricity output (GWh)                  14523.0000
# Renewable sources        Electricity output (GWh)                 436961.0000
# Total                    Electricity output (GWh)                 515745.0000
#
#                                                                          2011  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2133.8480
#                          Imports (ktoe)                            13683.8364
#                          Exports (ktoe)                              -40.4704
#                          Total energy supply (ktoe)                15448.4499
#                          Electricity, CHP and heat plants (ktoe)   -2723.8061
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            26792.7583
# Fossil fuels             Electricity output (GWh)                  52070.0000
# Nuclear                  Electricity output (GWh)                  15659.0000
# Renewable sources        Electricity output (GWh)                 463472.0000
# Total                    Electricity output (GWh)                 531757.0000
#
#                                                                          2012  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2517.1827
#                          Imports (ktoe)                            12251.9565
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                15296.0633
#                          Electricity, CHP and heat plants (ktoe)   -3603.1951
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            27204.5577
# Fossil fuels             Electricity output (GWh)                  80266.0000
# Nuclear                  Electricity output (GWh)                  16038.0000
# Renewable sources        Electricity output (GWh)                 456037.0000
# Total                    Electricity output (GWh)                 552624.0000
#
#                                                                          2013  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          3298.4887
#                          Imports (ktoe)                            13351.2664
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                16483.4638
#                          Electricity, CHP and heat plants (ktoe)   -5172.8680
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            26936.9641
# Fossil fuels             Electricity output (GWh)                 116971.0000
# Nuclear                  Electricity output (GWh)                  15450.0000
# Renewable sources        Electricity output (GWh)                 438338.0000
# Total                    Electricity output (GWh)                 571098.0000
#
#                                                                          2014  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          3060.0665
#                          Imports (ktoe)                            14670.6591
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                17530.4798
#                          Electricity, CHP and heat plants (ktoe)   -6090.8547
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            27205.1483
# Fossil fuels             Electricity output (GWh)                 142558.0000
# Nuclear                  Electricity output (GWh)                  15378.0000
# Renewable sources        Electricity output (GWh)                 432354.0000
# Total                    Electricity output (GWh)                 590651.0000
#
#                                                                          2015  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          3066.4350
#                          Imports (ktoe)                            14846.5685
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                17682.8248
#                          Electricity, CHP and heat plants (ktoe)   -6239.6668
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            26870.2953
# Fossil fuels             Electricity output (GWh)                 135654.0000
# Nuclear                  Electricity output (GWh)                  14734.0000
# Renewable sources        Electricity output (GWh)                 430874.0000
# Total                    Electricity output (GWh)                 581652.0000
#
#                                                                          2016  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          2635.7447
#                          Imports (ktoe)                            13672.0983
#                          Exports (ktoe)                                0.0000
#                          Total energy supply (ktoe)                15921.2404
#                          Electricity, CHP and heat plants (ktoe)   -5997.2385
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            26313.2245
# Fossil fuels             Electricity output (GWh)                  97214.0000
# Nuclear                  Electricity output (GWh)                  15864.0000
# Renewable sources        Electricity output (GWh)                 465420.0000
# Total                    Electricity output (GWh)                 578889.0000
#
#                                                                          2017  \
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1930.8901
#                          Imports (ktoe)                            15094.1775
#                          Exports (ktoe)                               -0.4147
#                          Total energy supply (ktoe)                16779.1376
#                          Electricity, CHP and heat plants (ktoe)   -5308.0738
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            27654.3503
# Fossil fuels             Electricity output (GWh)                 106564.4970
# Nuclear                  Electricity output (GWh)                  15739.1960
# Renewable sources        Electricity output (GWh)                 466651.1160
# Total                    Electricity output (GWh)                 589401.3810
#
#                                                                          2018
# Product                  Flow
# Coal, peat and oil shale Production (ktoe)                          1930.0074
#                          Imports (ktoe)                            15077.3357
#                          Exports (ktoe)                               -0.4147
#                          Total energy supply (ktoe)                16417.2087
#                          Electricity, CHP and heat plants (ktoe)   -4844.1290
# ...                                                                       ...
# Total                    Other final consumption (ktoe)            26795.7627
# Fossil fuels             Electricity output (GWh)                  90432.7140
# Nuclear                  Electricity output (GWh)                  15673.8870
# Renewable sources        Electricity output (GWh)                 494817.9440
# Total                    Electricity output (GWh)                 601371.1580
#
# [112 rows x 29 columns]

# %%
def predict_data(df,label):
    df = df.transpose()
    x = df[label].index
    y = df[label]
    lm=LinearRegression()
    lm.fit(x.values.reshape(-1,1),y)

    print(f"Modelo Previsto de {label} x Modelo Original")

    predictModel =  lm.predict(np.array(df[label].index.tolist()).reshape(-1, 1))
    pd.Series(data=predictModel,index=df[label].index).plot()
    df[label].plot()
    plt.show()

    print(f"Modelo Original como previsão de 4 anos no futuro")
    cols_predict =[2018,2019,2020,2021,2022]
    predictModel =  lm.predict(np.array(cols_predict).reshape(-1, 1))
    pd.Series(data=predictModel,index=cols_predict).plot()
    df[label].plot()
    plt.show()

# %% [markdown]
# ### Predizendo produção de energia renovavel nos proximos 4 anos

# %%
renew = br.loc[('Renewable sources')]
predict_data(renew,'Electricity output (GWh)')
# Out:
# Modelo Previsto de Electricity output (GWh) x Modelo Original
# Modelo Original como previsão de 4 anos no futuro

# %% [markdown]
# ### Predizendo produção de energias não-renovavel nos proximos 4 anos

# %%
not_renew = br.loc[('Fossil fuels')]
predict_data(not_renew,'Electricity output (GWh)')
# Out:
# Modelo Previsto de Electricity output (GWh) x Modelo Original
# Modelo Original como previsão de 4 anos no futuro

# %% [markdown]
# ### Predizendo produção de energias nuclear nos proximos 4 anos

# %%
nuclear = br.loc[('Fossil fuels')]
predict_data(nuclear,'Electricity output (GWh)')
# Out:
# Modelo Previsto de Electricity output (GWh) x Modelo Original
# Modelo Original como previsão de 4 anos no futuro
